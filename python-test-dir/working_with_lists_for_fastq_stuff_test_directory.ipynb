# %%
i = 0
j = i + 4
print(i)
print(j)
# Out:
# 0
# 4

# %%
new_list=[*range(0,1000,1)]

# %%
with open(r'test.txt', 'w') as tf:
    for line in new_list:
        tf.write("%i\n" %line)
    print('Done')
# Out:
# Done

# %%
file = open(r'test.txt', 'r')
lines = file.readlines()
numlines = len(lines)
print("numlines :", numlines)
# Out:
# numlines : 1000

# %%
i = 0
print("read1: ", lines[i:i+4])
j = i + 4
print("read2: ", lines[j:j+4])
# Out:
# read1:  ['0\n', '1\n', '2\n', '3\n']
# read2:  ['4\n', '5\n', '6\n', '7\n']

# %%
for i in range(0,numlines,8):
    print("read1: ", lines[i:i+4])
    print("read2: ", lines[i+4:i+8])
# Out:
# read1:  ['0\n', '1\n', '2\n', '3\n']
# read2:  ['4\n', '5\n', '6\n', '7\n']
# read1:  ['8\n', '9\n', '10\n', '11\n']
# read2:  ['12\n', '13\n', '14\n', '15\n']
# read1:  ['16\n', '17\n', '18\n', '19\n']
# read2:  ['20\n', '21\n', '22\n', '23\n']
# read1:  ['24\n', '25\n', '26\n', '27\n']
# read2:  ['28\n', '29\n', '30\n', '31\n']
# read1:  ['32\n', '33\n', '34\n', '35\n']
# read2:  ['36\n', '37\n', '38\n', '39\n']
# read1:  ['40\n', '41\n', '42\n', '43\n']
# read2:  ['44\n', '45\n', '46\n', '47\n']
# read1:  ['48\n', '49\n', '50\n', '51\n']
# read2:  ['52\n', '53\n', '54\n', '55\n']
# read1:  ['56\n', '57\n', '58\n', '59\n']
# read2:  ['60\n', '61\n', '62\n', '63\n']
# read1:  ['64\n', '65\n', '66\n', '67\n']
# read2:  ['68\n', '69\n', '70\n', '71\n']
# read1:  ['72\n', '73\n', '74\n', '75\n']
# read2:  ['76\n', '77\n', '78\n', '79\n']
# read1:  ['80\n', '81\n', '82\n', '83\n']
# read2:  ['84\n', '85\n', '86\n', '87\n']
# read1:  ['88\n', '89\n', '90\n', '91\n']
# ...

# %%
# OK COOL I GOT IT NOW!!!

# %%
from checkPaired import *

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 checkPaired(paired_file)
#
# NameError: name 'checkPaired' is not defined
